# %%
# Boilerplate: This block goes into every notebook.
# It sets up the environment, installs the requirements, and checks for the required environment variables.

from IPython.display import clear_output
from dotenv import load_dotenv
import os

requirements_installed = False
max_retries = 3
retries = 0
REQUIRED_ENV_VARS = ["OPENAI_API_KEY"]


def install_requirements():
    """Installs the requirements from requirements.txt file"""
    global requirements_installed
    if requirements_installed:
        print("Requirements already installed.")
        return

    print("Installing requirements...")
    install_status = os.system("pip install -r requirements.txt")
    if install_status == 0:
        print("Requirements installed successfully.")
        requirements_installed = True
    else:
        print("Failed to install requirements.")
        if retries < max_retries:
            print("Retrying...")
            retries += 1
            return install_requirements()
        exit(1)
    return


def setup_env():
    """Sets up the environment variables"""

    def check_env(env_var):
        value = os.getenv(env_var)
        if value is None:
            print(f"Please set the {env_var} environment variable.")
            exit(1)
        else:
            print(f"{env_var} is set.")

    load_dotenv(override=True, dotenv_path=".env")

    variables_to_check = REQUIRED_ENV_VARS

    for var in variables_to_check:
        check_env(var)


install_requirements()
clear_output()
setup_env()
print("🚀 Setup complete. Continue to the next cell.")
# Out:
# OPENAI_API_KEY is set.
# 🚀 Setup complete. Continue to the next cell.

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper
import json


def search_internet(query: str) -> str:
    """
    Searches the internet using Google Serper API.

    Args:
        query: The search query.

    Returns:
        str: The search results in JSON format.
    """
    search = GoogleSerperAPIWrapper()
    search_results = search.results(query)
    search_results_json = json.dumps(search_results, indent=4)
    return search_results_json

# %%
from openai import OpenAI
import json
from copy import deepcopy

openai = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

tools = [
    {
        "type": "function",
        "function": {
            "name": "search_internet",
            "description": "Searches the internet with the given query.",
            "parameters": {
                "type": "object",
                "properties": {
                    "query": {"type": "string", "description": "The search query."},
                },
                "required": ["query"],
                "additionalProperties": False,
            },
            "strict": True,
        },
    }
]

TOOL_MAP = {
    "search_internet": search_internet,
}


def process_tools_and_update_messages(
    messages, tool_calls, last_message, show_tool_outputs=False
):
    """
    Processes the tools and updates the messages.

    Args:
        messages: The messages to update.
        tool_calls: The tool calls to process.

    Returns:
        list: The updated messages.
    """
    print("BEFORE: ", messages)
    updated_messages = deepcopy(messages)

    for tool_call in tool_calls:
        name = tool_call.function.name
        if show_tool_outputs:
            print(f"Processing tool call: {name}")
        args = json.loads(tool_call.function.arguments)
        func = TOOL_MAP.get(name)

        if not func:
            print(f"Function {name} not found.")
            continue

        # call the tool function
        tool_output = func(**args)

        if show_tool_outputs:
            print(f"Tool output: {tool_output}")

        # Append the assistant's function call message
        updated_messages.append(last_message)
        updated_messages.append(
            {
                "role": "tool",
                "tool_call_id": tool_call.id,
                "content": json.dumps(tool_output),
            }
        )
    print("AFTER: ", updated_messages)
    return updated_messages


def llm(prompt: str, max_tool_iters=10, show_tool_outputs=False) -> str:
    """
    Calls the OpenAI language model with the given prompt.

    Args:
        prompt: The prompt to pass to the language model.
        max_tokens: The maximum number of tokens to generate.

    Returns:
        str: The response from the language model.
    """

    messages = [
        {
            "role": "system",
            "content": f"""
                        You are a helpful assistant. 
                        Use the provided tools to assist the user if required.
                        TOOLS: {json.dumps(tools, indent=4)}
                        """,
        },
        {"role": "user", "content": prompt},
    ]

    response = openai.chat.completions.create(
        model="gpt-4o",
        messages=messages,
        tools=tools,
    )
    last_message = response.choices[0].message
    tool_calls = response.choices[0].message.tool_calls
    messages = process_tools_and_update_messages(
        messages,
        tool_calls,
        last_message=last_message,
        show_tool_outputs=show_tool_outputs,
    )
    # iters = 0

    # while tool_calls and len(tool_calls) > 0 and iters < max_tool_iters:
    #     if show_tool_outputs:
    #         print(f"Processing tool calls. Iteration: {iters}.")
    #         print(f"Tool calls: {tool_calls}")

    #     response = openai.chat.completions.create(
    #         model="gpt-4o",
    #         messages=messages,
    #         tools=tools,
    #     )
    #     tool_calls = response.choices[0].message.tool_calls
    #     last_message = response.choices[0].message
    #     messages = process_tools_and_update_messages(
    #         messages,
    #         tool_calls,
    #         last_message=last_message,
    #         show_tool_outputs=show_tool_outputs,
    #     )
    #     iters += 1

    response = openai.chat.completions.create(
        model="gpt-4o",
        messages=messages,
        tools=tools,
    )

    return response.choices[0].message.content

# %%
query = "What is the time right now in NYC and Mumbai?"

response = llm(query, show_tool_outputs=True)

print(response)
# Out:
# BEFORE:  [{'role': 'system', 'content': '\n                        You are a helpful assistant. \n                        Use the provided tools to assist the user if required.\n                        TOOLS: [\n    {\n        "type": "function",\n        "function": {\n            "name": "search_internet",\n            "description": "Searches the internet with the given query.",\n            "parameters": {\n                "type": "object",\n                "properties": {\n                    "query": {\n                        "type": "string",\n                        "description": "The search query."\n                    }\n                },\n                "required": [\n                    "query"\n                ],\n                "additionalProperties": false\n            },\n            "strict": true\n        }\n    }\n]\n                        '}, {'role': 'user', 'content': 'What is the time right now in NYC and Mumbai?'}]
# Processing tool call: search_internet
# Tool output: {
#     "searchParameters": {
#         "q": "current time in New York City",
#         "gl": "us",
#         "hl": "en",
#         "type": "search",
#         "num": 10,
#         "engine": "google"
#     },
#     "answerBox": {
#         "title": "New York, NY / Local Time",
#         "answer": "4:16\u202fPM"
#     },
#     "organic": [
#         {
#             "title": "Current Local Time in New York, New York, USA - Time and Date",
#             "link": "https://www.timeanddate.com/worldclock/usa/new-york",
#             "snippet": "Time Zone: EST (Eastern Standard Time) UTC/GMT -5 hours. Daylight Saving Time starts on Sunday, March 9, 2025 at 2:00 am.",
#             "sitelinks": [
#                 {
#                     "title": "New York (NY)",
#                     "link": "https://www.timeanddate.com/worldclock/usa/new-york-state"
#                 },
#                 {
#                     "title": "Time Zone",
#                     "link": "https://www.timeanddate.com/time/zone/usa/new-york"
#                 },
#                 {
#                     "title": "Weather",
#                     "link": "https://www.timeanddate.com/weather/usa/new-york"
#                 },
#                 {
#                     "title": "Sun & Moon",
#                     "link": "https://www.timeanddate.com/astronomy/usa/new-york"
#                 }
#             ],
#             "position": 1
#         },
#         {
#             "title": "Time in New York, United States now",
#             "link": "https://time.is/New_York",
#             "snippet": "Time zone info for New York \u00b7 Switched to UTC -5 / Eastern Standard Time (EST). \u00b7 The time was set back one hour from 02:00AM to 01:00AM local time.",
#             "position": 2
#         },
#         {
#             "title": "Current Local Time in New York, United States",
#             "link": "https://www.timeanddate.com/worldclock/usa/new-york-state",
#             "snippet": "Current Local Time in New York, United States ; Mount Vernon, Thu 3:08 pm ; New City, Thu 3:08 pm ; New York, Thu 3:08 pm ; Olean, Thu 3:08 pm.",
#             "position": 3
#         },
#         {
#             "title": "Current local time in New York, United States - WorldTimeServer.com",
#             "link": "https://www.worldtimeserver.com/current_time_in_US-NY.aspx",
#             "snippet": "Current local time and date in New York, United States from a trusted independent resource.",
#             "position": 4
#         },
#         {
#             "title": "Time in New York, United States - 24 Time Zones",
#             "link": "https://24timezones.com/New-York/time",
#             "snippet": "Current local time in New York. New York. 22428PM. Friday, February 7, 2025. New York time to your local time converter. New York - local time right now, summer ...",
#             "position": 5
#         },
#         {
#             "title": "Current Local Time in New York City, United States (New York)",
#             "link": "https://www.zeitverschiebung.net/en/city/5128581",
#             "snippet": "The time in New York City is currently 3 hours ahead of the time in America/Los_Angeles. Your determined time zone: America/Los_Angeles.",
#             "position": 6
#         },
#         {
#             "title": "Current Time & Time Zone For NYC, New York - Clock.Zone",
#             "link": "https://clock.zone/america/new-york",
#             "snippet": "In the moment when this page was generated, in NYC, New York it was Wednesday, February 12, 2025 7:00 PM Abbreviation for this time zone is EST . Difference to ...",
#             "position": 7
#         },
#         {
#             "title": "Current Local Time in Manhattan, United States (New York County ...",
#             "link": "https://www.zeitverschiebung.net/en/city/5125771",
#             "snippet": "Time Difference ... The time in Manhattan is currently 3 hours ahead of the time in America/Los_Angeles. Your determined time zone: America/Los_Angeles.",
#             "position": 8
#         },
#         {
#             "title": "Current local time in New York, New York - 24 Time Zones",
#             "link": "https://24timezones.com/usa_time/ny_bronx/new_york.php",
#             "snippet": "Current local time in New York, Bronx County, New York, Eastern Time Zone - daylight saving time change dates 2025. Local Time in New York, NY. 2:24:23 PM, ...",
#             "position": 9
#         },
#         {
#             "title": "Current time in New York, United States - LogWork.com",
#             "link": "https://logwork.com/current-time-in-new-york-united-states",
#             "snippet": "Current New York time zone is (EDT UTC-4) Standard time (EST, UTC-5) will start 02 November 2025. New York is 6 hours behind Paris (+6).",
#             "position": 10
#         }
#     ],
#     "peopleAlsoAsk": [
#         {
#             "question": "Does NYC have 2 time zones?",
#             "snippet": "New York is located in Eastern Time Zone. In New York, as in all of America, summer time starts on the second Sunday of March until the first Sunday in November. If you are traveling during the hourly change to New York, you are going to hear about the Daylight Saving Time.",
#             "title": "New York Time Zone, Daylight Saving Time and Jet Lag",
#             "link": "https://www.newyorkwelcome.net/explore/what-to-know/time-zone-and-jet-leg.htm"
#         },
#         {
#             "question": "Is New York currently EST or EDT?",
#             "snippet": "Offset\nTime Zone Abbreviation & Name\n\nUTC -5\nEST\nEastern Standard Time",
#             "title": "Time Zones in New York, United States - Time and Date",
#             "link": "https://www.timeanddate.com/time/zone/usa/new-york-state"
#         },
#         {
#             "question": "What time would it be in New York right now?",
#             "snippet": "Current Local Time in Locations in New York with Links for More Information (34 Locations)\n\nNew York\nWed 2:34 am\nOlean\nWed 2:34 am\nPlattsburgh\nWed 2:34 am\nPoughkeepsie\nWed 2:34 am",
#             "title": "Current Local Time in New York, United States",
#             "link": "https://www.timeanddate.com/worldclock/usa/new-york-state"
#         },
#         {
#             "question": "Is NYC 3 hours ahead of California?",
#             "snippet": "Time Zone Difference: New York operates in the Eastern Time Zone, which is three hours ahead of California's Pacific Time. When it's 12:00 PM in California, it's already 3:00 PM in New York.",
#             "title": "What States are 3 Hours Ahead of California? - GeeksforGeeks",
#             "link": "https://www.geeksforgeeks.org/states-3-hours-ahead-of-california/"
#         }
#     ],
#     "relatedSearches": [
#         {
#             "query": "Time in New York AM or PM"
#         },
#         {
#             "query": "Current time in new york city converter"
#         },
#         {
#             "query": "New York time zone"
#         },
#         {
#             "query": "Current time in new york city est"
#         },
#         {
#             "query": "Current time in new york city gmt"
#         },
#         {
#             "query": "Time in USA now AM or PM"
#         },
#         {
#             "query": "Time in New Jersey"
#         },
#         {
#             "query": "Time in Los Angeles"
#         }
#     ],
#     "credits": 1
# }
# Processing tool call: search_internet
# Tool output: {
#     "searchParameters": {
#         "q": "current time in Mumbai",
#         "gl": "us",
#         "hl": "en",
#         "type": "search",
#         "num": 10,
#         "engine": "google"
#     },
#     "answerBox": {
#         "title": "Mumbai, Maharashtra, India / Local Time",
#         "answer": "2:46\u202fAM"
#     },
#     "organic": [
#         {
#             "title": "Current Local Time in Mumbai, Maharashtra, India (Bombay)",
#             "link": "https://www.timeanddate.com/worldclock/india/mumbai",
#             "snippet": "Current Local Time in Mumbai, Maharashtra, India (Bombay) ... Moon Phase. Third Quarter February 20, 2025 11:02 pm.",
#             "sitelinks": [
#                 {
#                     "title": "Time Zone",
#                     "link": "https://www.timeanddate.com/time/zone/india/mumbai"
#                 },
#                 {
#                     "title": "Difference",
#                     "link": "https://www.timeanddate.com/time/difference/india/mumbai"
#                 },
#                 {
#                     "title": "Maharashtra",
#                     "link": "https://www.timeanddate.com/worldclock/india/maharashtra"
#                 },
#                 {
#                     "title": "Sunrise & Sunset",
#                     "link": "https://www.timeanddate.com/sun/india/mumbai"
#                 }
#             ],
#             "position": 1
#         },
#         {
#             "title": "Time in Mumbai, India now",
#             "link": "https://time.is/Mumbai",
#             "snippet": "Exact time now, time zone, time difference, sunrise/sunset time and key facts for Mumbai, India.",
#             "position": 2
#         },
#         {
#             "title": "Time in Mumbai, India - World Time Buddy",
#             "link": "https://www.worldtimebuddy.com/india-mumbai",
#             "snippet": "Current time zone for Mumbai, India is IST, whose offset is GMT+5.5. It currently does not observe Daylight Savings Time.",
#             "position": 3
#         },
#         {
#             "title": "Time Zone & Clock Changes in Mumbai, Maharashtra, India",
#             "link": "https://www.timeanddate.com/time/zone/india/mumbai",
#             "snippet": "Current: IST \u2014 India Standard Time. Current Offset: UTC/GMT +5:30 hours ... * All times are local Mumbai time. Data for the years before 1970 is not ...",
#             "position": 4
#         },
#         {
#             "title": "Current local time in Mumbai, India - WorldTimeServer.com",
#             "link": "https://www.worldtimeserver.com/current_time_in_IN.aspx?city=Mumbai",
#             "snippet": "Current local time and date in Mumbai, India from a trusted independent resource.",
#             "position": 5
#         },
#         {
#             "title": "Mumbai Time to EST Converter - World Time Buddy",
#             "link": "https://www.worldtimebuddy.com/india-mumbai-to-est",
#             "snippet": "This time zone converter lets you visually and very quickly convert Mumbai, India time to EST and vice-versa.",
#             "position": 6
#         },
#         {
#             "title": "Current Local Time in Mumbai, India (Maharashtra) - Time Difference",
#             "link": "https://www.zeitverschiebung.net/en/city/1275339",
#             "snippet": "The time in Mumbai is currently 13:30 hours ahead of the time in America/Los_Angeles. Your determined time zone: America/Los_Angeles.",
#             "sitelinks": [
#                 {
#                     "title": "Madrid, Spain",
#                     "link": "https://www.zeitverschiebung.net/en/difference/city/1275339/city/3117735"
#                 },
#                 {
#                     "title": "Frankfurt am Main, Germany",
#                     "link": "https://www.zeitverschiebung.net/en/difference/city/1275339/city/2925533"
#                 },
#                 {
#                     "title": "Paris, France",
#                     "link": "https://www.zeitverschiebung.net/en/difference/city/1275339/city/2988507"
#                 },
#                 {
#                     "title": "Berlin",
#                     "link": "https://www.zeitverschiebung.net/en/difference/city/1275339/city/2950159"
#                 }
#             ],
#             "position": 7
#         },
#         {
#             "title": "Time in Mumbai - Maharashtra, India - GMT",
#             "link": "https://greenwichmeantime.com/time/india/mumbai/",
#             "snippet": "Mumbai. 12:09 AM ; TZGMT. 6:39 PM ; TZLocal. 10:39 AM ...",
#             "position": 8
#         },
#         {
#             "title": "Current Time & Time Zone For Mumbai, India - Clock.Zone",
#             "link": "https://clock.zone/asia/mumbai",
#             "snippet": "In the moment when this page was generated, in Mumbai, India it was Thursday, February 13, 2025 5:30 AM Abbreviation for this time zone is IST .",
#             "position": 9
#         },
#         {
#             "title": "Time in Mumbai, India - UTC time",
#             "link": "https://currenttimeutc.com/india/mumbai/",
#             "snippet": "The current time in Mumbai is based on Indian Standard Time (IST), which is UTC+5:30 throughout the year as India does not observe Daylight Saving Time. Does ...",
#             "position": 10
#         }
#     ],
#     "peopleAlsoAsk": [
#         {
#             "question": "How many time zones are there in India?",
#             "snippet": "India uses only one time zone (even though it spans two geographical time zones) across the whole nation and all its territories, called Indian Standard Time (IST), which equates to UTC+05:30, i.e. five and a half hours ahead of Coordinated Universal Time (UTC).",
#             "title": "Time in India - Wikipedia",
#             "link": "https://en.wikipedia.org/wiki/Time_in_India"
#         },
#         {
#             "question": "What season is it in Mumbai right now?",
#             "snippet": "Travel Seasons\nMin/Max Temperature\nSeason\nMarch to May\n25-38 degrees\nSummer - Hot, humid and sweaty\nJune to September\n20-30 degrees\nMonsoon - Cool but heavy rains\nOctober to February\n10-35 degrees\nWinter - Cool and pleasant",
#             "title": "Best time to Visit Mumbai - Weather, Climate, Temperature Today",
#             "link": "https://www.thomascook.in/india-tourism/best-time-to-visit-mumbai"
#         },
#         {
#             "question": "Why is Mumbai time 30 minutes different?",
#             "snippet": "A few years ago, it was officially set as IST or Indian Standard Time. This is because India is in the middle of the longitude of 82.5\u00b0 E. After it became an independent country in 1947, India decided to be 30 minutes between the two countries which are Bangladesh and Pakistan.",
#             "title": "Why Does India Have a Different Time Zone? - india's culture",
#             "link": "https://www.iccrindia.net/2021/06/02/why-india-have-different-time-zone/"
#         },
#         {
#             "question": "Is the local time at Mumbai is not the same as the Indian Standard Time?",
#             "snippet": "The Indian Standard Time was adopted on 1 January 1906 during the British era with the phasing out of its precursor Madras Time (Railway Time), and after Independence in 1947, the Union government established IST as the official time for the whole country, although Kolkata and Mumbai retained their own local time ( ...",
#             "title": "Indian Standard Time - Wikipedia",
#             "link": "https://en.wikipedia.org/wiki/Indian_Standard_Time"
#         }
#     ],
#     "relatedSearches": [
#         {
#             "query": "Time in Mumbai with seconds"
#         },
#         {
#             "query": "Current time in mumbai pm or am"
#         },
#         {
#             "query": "Current time in mumbai and india"
#         },
#         {
#             "query": "Mumbai time zone"
#         },
#         {
#             "query": "Mumbai time zone UTC"
#         },
#         {
#             "query": "Current time in mumbai gmt"
#         },
#         {
#             "query": "Current time in India"
#         },
#         {
#             "query": "Time Zone in Mumbai Mall"
#         }
#     ],
#     "credits": 1
# }
# AFTER:  [{'role': 'system', 'content': '\n                        You are a helpful assistant. \n                        Use the provided tools to assist the user if required.\n                        TOOLS: [\n    {\n        "type": "function",\n        "function": {\n            "name": "search_internet",\n            "description": "Searches the internet with the given query.",\n            "parameters": {\n                "type": "object",\n                "properties": {\n                    "query": {\n                        "type": "string",\n                        "description": "The search query."\n                    }\n                },\n                "required": [\n                    "query"\n                ],\n                "additionalProperties": false\n            },\n            "strict": true\n        }\n    }\n]\n                        '}, {'role': 'user', 'content': 'What is the time right now in NYC and Mumbai?'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_YdEEht3aFc9DuFq5ttcZ1oVX', function=Function(arguments='{"query": "current time in New York City"}', name='search_internet'), type='function'), ChatCompletionMessageToolCall(id='call_5cABr4buTxMrB84MdOpMICHv', function=Function(arguments='{"query": "current time in Mumbai"}', name='search_internet'), type='function')]), {'role': 'tool', 'tool_call_id': 'call_YdEEht3aFc9DuFq5ttcZ1oVX', 'content': '"{\\n    \\"searchParameters\\": {\\n        \\"q\\": \\"current time in New York City\\",\\n        \\"gl\\": \\"us\\",\\n        \\"hl\\": \\"en\\",\\n        \\"type\\": \\"search\\",\\n        \\"num\\": 10,\\n        \\"engine\\": \\"google\\"\\n    },\\n    \\"answerBox\\": {\\n        \\"title\\": \\"New York, NY / Local Time\\",\\n        \\"answer\\": \\"4:16\\\\u202fPM\\"\\n    },\\n    \\"organic\\": [\\n        {\\n            \\"title\\": \\"Current Local Time in New York, New York, USA - Time and Date\\",\\n            \\"link\\": \\"https://www.timeanddate.com/worldclock/usa/new-york\\",\\n            \\"snippet\\": \\"Time Zone: EST (Eastern Standard Time) UTC/GMT -5 hours. Daylight Saving Time starts on Sunday, March 9, 2025 at 2:00 am.\\",\\n            \\"sitelinks\\": [\\n                {\\n                    \\"title\\": \\"New York (NY)\\",\\n                    \\"link\\": \\"https://www.timeanddate.com/worldclock/usa/new-york-state\\"\\n                },\\n                {\\n                    \\"title\\": \\"Time Zone\\",\\n                    \\"link\\": \\"https://www.timeanddate.com/time/zone/usa/new-york\\"\\n                },\\n                {\\n                    \\"title\\": \\"Weather\\",\\n                    \\"link\\": \\"https://www.timeanddate.com/weather/usa/new-york\\"\\n                },\\n                {\\n                    \\"title\\": \\"Sun & Moon\\",\\n                    \\"link\\": \\"https://www.timeanddate.com/astronomy/usa/new-york\\"\\n                }\\n            ],\\n            \\"position\\": 1\\n        },\\n        {\\n            \\"title\\": \\"Time in New York, United States now\\",\\n            \\"link\\": \\"https://time.is/New_York\\",\\n            \\"snippet\\": \\"Time zone info for New York \\\\u00b7 Switched to UTC -5 / Eastern Standard Time (EST). \\\\u00b7 The time was set back one hour from 02:00AM to 01:00AM local time.\\",\\n            \\"position\\": 2\\n        },\\n        {\\n            \\"title\\": \\"Current Local Time in New York, United States\\",\\n            \\"link\\": \\"https://www.timeanddate.com/worldclock/usa/new-york-state\\",\\n            \\"snippet\\": \\"Current Local Time in New York, United States ; Mount Vernon, Thu 3:08 pm ; New City, Thu 3:08 pm ; New York, Thu 3:08 pm ; Olean, Thu 3:08 pm.\\",\\n            \\"position\\": 3\\n        },\\n        {\\n            \\"title\\": \\"Current local time in New York, United States - W ...
# None
